# %%
import os

os.environ["KERAS_BACKEND"] = "tensorflow"

import random
import numpy as np
from glob import glob
from PIL import Image, ImageOps
import matplotlib.pyplot as plt

from tensorflow.keras import layers
import tensorflow as tf

# %%
# !wget https://huggingface.co/datasets/geekyrakshit/LoL-Dataset/resolve/main/lol_dataset.zip
# !unzip -q lol_dataset.zip && rm lol_dataset.zip

# %% [markdown]
# ## Creating a TensorFlow Dataset
#
# We use 300 image pairs from the LoL Dataset's training set for training,
# and we use the remaining 185 image pairs for validation.
# We generate random crops of size `128 x 128` from the image pairs to be
# used for both training and validation.

# %%
random.seed(10)

IMAGE_SIZE = 128
BATCH_SIZE = 4
MAX_TRAIN_IMAGES = 300


def read_image(image_path):
    image = tf.io.read_file(image_path)
    image = tf.image.decode_png(image, channels=3)
    image.set_shape([None, None, 3])
    image = tf.cast(image, dtype=tf.float32) / 255.0
    return image


def random_crop(low_image, enhanced_image):
    low_image_shape = tf.shape(low_image)[:2]
    low_w = tf.random.uniform(
        shape=(), maxval=low_image_shape[1] - IMAGE_SIZE + 1, dtype=tf.int32
    )
    low_h = tf.random.uniform(
        shape=(), maxval=low_image_shape[0] - IMAGE_SIZE + 1, dtype=tf.int32
    )
    low_image_cropped = low_image[
        low_h : low_h + IMAGE_SIZE, low_w : low_w + IMAGE_SIZE
    ]
    enhanced_image_cropped = enhanced_image[
        low_h : low_h + IMAGE_SIZE, low_w : low_w + IMAGE_SIZE
    ]
    # in order to avoid `NONE` during shape inference
    low_image_cropped.set_shape([IMAGE_SIZE, IMAGE_SIZE, 3])
    enhanced_image_cropped.set_shape([IMAGE_SIZE, IMAGE_SIZE, 3])
    return low_image_cropped, enhanced_image_cropped


def load_data(low_light_image_path, enhanced_image_path):
    low_light_image = read_image(low_light_image_path)
    enhanced_image = read_image(enhanced_image_path)
    low_light_image, enhanced_image = random_crop(low_light_image, enhanced_image)
    return low_light_image, enhanced_image


def get_dataset(low_light_images, enhanced_images):
    dataset = tf.data.Dataset.from_tensor_slices((low_light_images, enhanced_images))
    dataset = dataset.map(load_data, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)
    return dataset

# %%
train_low_light_images = sorted(glob("lol_dataset/our485/low/*"))[:MAX_TRAIN_IMAGES]
train_enhanced_images = sorted(glob("lol_dataset/our485/high/*"))[:MAX_TRAIN_IMAGES]

val_low_light_images = sorted(glob("lol_dataset/our485/low/*"))[MAX_TRAIN_IMAGES:]
val_enhanced_images = sorted(glob("lol_dataset/our485/high/*"))[MAX_TRAIN_IMAGES:]

test_low_light_images = sorted(glob("lol_dataset/eval15/low/*"))
test_enhanced_images = sorted(glob("lol_dataset/eval15/high/*"))

# %%
train_low_light_images[:5]
# Out:
# ['lol_dataset/our485/low\\10.png',
#  'lol_dataset/our485/low\\100.png',
#  'lol_dataset/our485/low\\101.png',
#  'lol_dataset/our485/low\\102.png',
#  'lol_dataset/our485/low\\103.png']

# %%
train_enhanced_images[:5]
# Out:
# ['lol_dataset/our485/high\\10.png',
#  'lol_dataset/our485/high\\100.png',
#  'lol_dataset/our485/high\\101.png',
#  'lol_dataset/our485/high\\102.png',
#  'lol_dataset/our485/high\\103.png']

# %%
train_dataset = get_dataset(train_low_light_images, train_enhanced_images)
val_dataset = get_dataset(val_low_light_images, val_enhanced_images)


print("Train Dataset:", train_dataset.element_spec)
print("Val Dataset:", val_dataset.element_spec)
# Out:
# Train Dataset: (TensorSpec(shape=(4, 128, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(4, 128, 128, 3), dtype=tf.float32, name=None))
# Val Dataset: (TensorSpec(shape=(4, 128, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(4, 128, 128, 3), dtype=tf.float32, name=None))

# %% [markdown]
# ## MIRNet Model
#
# Here are the main features of the MIRNet model:
#
# - A feature extraction model that computes a complementary set of features across multiple
# spatial scales, while maintaining the original high-resolution features to preserve
# precise spatial details.
# - A regularly repeated mechanism for information exchange, where the features across
# multi-resolution branches are progressively fused together for improved representation
# learning.
# - A new approach to fuse multi-scale features using a selective kernel network
# that dynamically combines variable receptive fields and faithfully preserves
# the original feature information at each spatial resolution.
# - A recursive residual design that progressively breaks down the input signal
# in order to simplify the overall learning process, and allows the construction
# of very deep networks.
#
#
# ![](https://raw.githubusercontent.com/soumik12345/MIRNet/master/assets/mirnet_architecture.png)

# %% [markdown]
# ### Selective Kernel Feature Fusion
#
# The Selective Kernel Feature Fusion or SKFF module performs dynamic adjustment of
# receptive fields via two operations: **Fuse** and **Select**. The Fuse operator generates
# global feature descriptors by combining the information from multi-resolution streams.
# The Select operator uses these descriptors to recalibrate the feature maps (of different
# streams) followed by their aggregation.
#
# **Fuse**: The SKFF receives inputs from three parallel convolution streams carrying
# different scales of information. We first combine these multi-scale features using an
# element-wise sum, on which we apply Global Average Pooling (GAP) across the spatial
# dimension. Next, we apply a channel- downscaling convolution layer to generate a compact
# feature representation which passes through three parallel channel-upscaling convolution
# layers (one for each resolution stream) and provides us with three feature descriptors.
#
# **Select**: This operator applies the softmax function to the feature descriptors to
# obtain the corresponding activations that are used to adaptively recalibrate multi-scale
# feature maps. The aggregated features are defined as the sum of product of the corresponding
# multi-scale feature and the feature descriptor.
#
# ![](https://i.imgur.com/7U6ixF6.png)

# %%
def selective_kernel_feature_fusion(
    multi_scale_feature_1, multi_scale_feature_2, multi_scale_feature_3
):
    channels = list(multi_scale_feature_1.shape)[-1]
    combined_feature = layers.Add()(
        [multi_scale_feature_1, multi_scale_feature_2, multi_scale_feature_3]
    )
    gap = layers.GlobalAveragePooling2D()(combined_feature)
    channel_wise_statistics = layers.Reshape((1, 1, channels))(gap)
    compact_feature_representation = layers.Conv2D(
        filters=channels // 8, kernel_size=(1, 1), activation="relu"
    )(channel_wise_statistics)
    feature_descriptor_1 = layers.Conv2D(
        channels, kernel_size=(1, 1), activation="softmax"
    )(compact_feature_representation)
    feature_descriptor_2 = layers.Conv2D(
        channels, kernel_size=(1, 1), activation="softmax"
    )(compact_feature_representation)
    feature_descriptor_3 = layers.Conv2D(
        channels, kernel_size=(1, 1), activation="softmax"
    )(compact_feature_representation)
    feature_1 = multi_scale_feature_1 * feature_descriptor_1
    feature_2 = multi_scale_feature_2 * feature_descriptor_2
    feature_3 = multi_scale_feature_3 * feature_descriptor_3
    aggregated_feature = layers.Add()([feature_1, feature_2, feature_3])
    return aggregated_feature

# %% [markdown]
# ### Dual Attention Unit
#
# The Dual Attention Unit or DAU is used to extract features in the convolutional streams.
# While the SKFF block fuses information across multi-resolution branches, we also need a
# mechanism to share information within a feature tensor, both along the spatial and the
# channel dimensions which is done by the DAU block. The DAU suppresses less useful
# features and only allows more informative ones to pass further. This feature
# recalibration is achieved by using **Channel Attention** and **Spatial Attention**
# mechanisms.
#
# The **Channel Attention** branch exploits the inter-channel relationships of the
# convolutional feature maps by applying squeeze and excitation operations. Given a feature
# map, the squeeze operation applies Global Average Pooling across spatial dimensions to
# encode global context, thus yielding a feature descriptor. The excitation operator passes
# this feature descriptor through two convolutional layers followed by the sigmoid gating
# and generates activations. Finally, the output of Channel Attention branch is obtained by
# rescaling the input feature map with the output activations.
#
# The **Spatial Attention** branch is designed to exploit the inter-spatial dependencies of
# convolutional features. The goal of Spatial Attention is to generate a spatial attention
# map and use it to recalibrate the incoming features. To generate the spatial attention
# map, the Spatial Attention branch first independently applies Global Average Pooling and
# Max Pooling operations on input features along the channel dimensions and concatenates
# the outputs to form a resultant feature map which is then passed through a convolution
# and sigmoid activation to obtain the spatial attention map. This spatial attention map is
# then used to rescale the input feature map.
#
# ![](https://i.imgur.com/Dl0IwQs.png)

# %%
class ChannelPooling(layers.Layer):
    def __init__(self, axis=-1, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.axis = axis
        self.concat = layers.Concatenate(axis=self.axis)

    def call(self, inputs):
        average_pooling = tf.expand_dims(tf.reduce_mean(inputs, axis=-1), axis=-1)
        max_pooling = tf.expand_dims(tf.reduce_max(inputs, axis=-1), axis=-1)
        return self.concat([average_pooling, max_pooling])

    def get_config(self):
        config = super().get_config()
        config.update({"axis": self.axis})


def spatial_attention_block(input_tensor):
    compressed_feature_map = ChannelPooling(axis=-1)(input_tensor)
    feature_map = layers.Conv2D(1, kernel_size=(1, 1))(compressed_feature_map)
    feature_map = tf.keras.activations.sigmoid(feature_map)
    return input_tensor * feature_map


def channel_attention_block(input_tensor):
    channels = list(input_tensor.shape)[-1]
    average_pooling = layers.GlobalAveragePooling2D()(input_tensor)
    feature_descriptor = layers.Reshape((1, 1, channels))(average_pooling)
    feature_activations = layers.Conv2D(
        filters=channels // 8, kernel_size=(1, 1), activation="relu"
    )(feature_descriptor)
    feature_activations = layers.Conv2D(
        filters=channels, kernel_size=(1, 1), activation="sigmoid"
    )(feature_activations)
    return input_tensor * feature_activations


def dual_attention_unit_block(input_tensor):
    channels = list(input_tensor.shape)[-1]
    feature_map = layers.Conv2D(
        channels, kernel_size=(3, 3), padding="same", activation="relu"
    )(input_tensor)
    feature_map = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(
        feature_map
    )
    channel_attention = channel_attention_block(feature_map)
    spatial_attention = spatial_attention_block(feature_map)
    concatenation = layers.Concatenate(axis=-1)([channel_attention, spatial_attention])
    concatenation = layers.Conv2D(channels, kernel_size=(1, 1))(concatenation)
    return layers.Add()([input_tensor, concatenation])

# %% [markdown]
# ### Multi-Scale Residual Block
#
# The Multi-Scale Residual Block is capable of generating a spatially-precise output by
# maintaining high-resolution representations, while receiving rich contextual information
# from low-resolutions. The MRB consists of multiple (three in this paper)
# fully-convolutional streams connected in parallel. It allows information exchange across
# parallel streams in order to consolidate the high-resolution features with the help of
# low-resolution features, and vice versa. The MIRNet employs a recursive residual design
# (with skip connections) to ease the flow of information during the learning process. In
# order to maintain the residual nature of our architecture, residual resizing modules are
# used to perform downsampling and upsampling operations that are used in the Multi-scale
# Residual Block.
#
# ![](https://i.imgur.com/wzZKV57.png)

# %%
# Recursive Residual Modules


def down_sampling_module(input_tensor):
    channels = list(input_tensor.shape)[-1]
    main_branch = layers.Conv2D(channels, kernel_size=(1, 1), activation="relu")(
        input_tensor
    )
    main_branch = layers.Conv2D(
        channels, kernel_size=(3, 3), padding="same", activation="relu"
    )(main_branch)
    main_branch = layers.MaxPooling2D()(main_branch)
    main_branch = layers.Conv2D(channels * 2, kernel_size=(1, 1))(main_branch)
    skip_branch = layers.MaxPooling2D()(input_tensor)
    skip_branch = layers.Conv2D(channels * 2, kernel_size=(1, 1))(skip_branch)
    return layers.Add()([skip_branch, main_branch])


def up_sampling_module(input_tensor):
    channels = list(input_tensor.shape)[-1]
    main_branch = layers.Conv2D(channels, kernel_size=(1, 1), activation="relu")(
        input_tensor
    )
    main_branch = layers.Conv2D(
        channels, kernel_size=(3, 3), padding="same", activation="relu"
    )(main_branch)
    main_branch = layers.UpSampling2D()(main_branch)
    main_branch = layers.Conv2D(channels // 2, kernel_size=(1, 1))(main_branch)
    skip_branch = layers.UpSampling2D()(input_tensor)
    skip_branch = layers.Conv2D(channels // 2, kernel_size=(1, 1))(skip_branch)
    return layers.Add()([skip_branch, main_branch])


# MRB Block
def multi_scale_residual_block(input_tensor, channels):
    # features
    level1 = input_tensor
    level2 = down_sampling_module(input_tensor)
    level3 = down_sampling_module(level2)
    # DAU
    level1_dau = dual_attention_unit_block(level1)
    level2_dau = dual_attention_unit_block(level2)
    level3_dau = dual_attention_unit_block(level3)
    # SKFF
    level1_skff = selective_kernel_feature_fusion(
        level1_dau,
        up_sampling_module(level2_dau),
        up_sampling_module(up_sampling_module(level3_dau)),
    )
    level2_skff = selective_kernel_feature_fusion(
        down_sampling_module(level1_dau),
        level2_dau,
        up_sampling_module(level3_dau),
    )
    level3_skff = selective_kernel_feature_fusion(
        down_sampling_module(down_sampling_module(level1_dau)),
        down_sampling_module(level2_dau),
        level3_dau,
    )
    # DAU 2
    level1_dau_2 = dual_attention_unit_block(level1_skff)
    level2_dau_2 = up_sampling_module((dual_attention_unit_block(level2_skff)))
    level3_dau_2 = up_sampling_module(
        up_sampling_module(dual_attention_unit_block(level3_skff))
    )
    # SKFF 2
    skff_ = selective_kernel_feature_fusion(level1_dau_2, level2_dau_2, level3_dau_2)
    conv = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(skff_)
    return layers.Add()([input_tensor, conv])

# %% [markdown]
# ### MIRNet Model

# %%
def recursive_residual_group(input_tensor, num_mrb, channels):
    conv1 = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(input_tensor)
    for _ in range(num_mrb):
        conv1 = multi_scale_residual_block(conv1, channels)
    conv2 = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(conv1)
    return layers.Add()([conv2, input_tensor])


def mirnet_model(num_rrg, num_mrb, channels):
    input_tensor = tf.keras.Input(shape=[None, None, 3])
    x1 = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(input_tensor)
    for _ in range(num_rrg):
        x1 = recursive_residual_group(x1, num_mrb, channels)
    conv = layers.Conv2D(3, kernel_size=(3, 3), padding="same")(x1)
    output_tensor = layers.Add()([input_tensor, conv])
    return tf.keras.Model(input_tensor, output_tensor)

# %%
model = mirnet_model(num_rrg=3, num_mrb=2, channels=64)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  conv2d (Conv2D)                (None, None, None,   1792        ['input_1[0][0]']
#                                 64)
#
#  conv2d_1 (Conv2D)              (None, None, None,   36928       ['conv2d[0][0]']
#                                 64)
#
#  conv2d_10 (Conv2D)             (None, None, None,   36928       ['conv2d_1[0][0]']
#                                 64)
#
#  conv2d_2 (Conv2D)              (None, None, None,   4160        ['conv2d_1[0][0]']
#                                 64)
#
#  conv2d_11 (Conv2D)             (None, None, None,   36928       ['conv2d_10[0][0]']
#                                 64)
#
#  conv2d_3 (Conv2D)              (None, None, None,   36928       ['conv2d_2[0][0]']
#                                 64)
#
#  global_average_pooling2d (Glob  (None, 64)          0           ['conv2d_11[0][0]']
#  alAveragePooling2D)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, None, None,   0          ['conv2d_1[0][0]']
#                                 64)
#
#  max_pooling2d (MaxPooling2D)   (None, None, None,   0           ['conv2d_3[0][0]']
#                                 64)
#
#  reshape (Reshape)              (None, 1, 1, 64)     0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  channel_pooling (ChannelPoolin  (None, None, None,   0          ['conv2d_11[0][0]']
#  g)                             2)
#
#  conv2d_5 (Conv2D)              (None, None, None,   8320        ['max_pooling2d_1[0][0]']
#                                 128)
#
#  conv2d_4 (Conv2D)              (None, None, None,   8320        ['max_pooling2d[0][0]']
#                                 128)
#
#  conv2d_12 (Conv2D)             (None, 1, 1, 8)      520         ['reshape[0][0]']
#
#  conv2d_14 (Conv2D)             (None, None, None,   3           ['channel_pooling[0][0]']
#                                 1)
#
#  add (Add)                      (None, None, None,   0           ['conv2d_5[0][0]',
#                                 128)                              'conv2d_4[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 1, 1, 64)     576         ['conv2d_12[0][0]']
#
#  tf.math.sigmoid (TFOpLambda)   (None, None, None,   0           ['conv2d_14[0][0]']
#                                 1)
#
#  conv2d_16 (Conv2D)             (None, None, None,   147584      ['add[0][0]']
#                                 128)
#
#  conv2d_6 (Conv2D)              (None, None, None,   16512       ['add[0][0]']
#                                 128)
#
#  tf.math.multiply (TFOpLambda)  (None, None, None,   0           ['conv2d_11[0][0]',
#                                 64)                               'conv2d_13[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, None, None,   0          ['conv2d_11[0][0]',
#  )                              64)                               'tf.math.sigmoid[0][0]']
#
#  conv2d_17 (Conv2D)             (None, None, None,   147584      ['conv2d_16[0][0]']
#                                 128)
#
#  conv2d_7 (Conv2D)              (None, None, None,   147584      ['conv2d_6[0][0]']
#                                 128)
#
#  concatenate_1 (Concatenate)    (None, None, None,   0           ['tf.math.multiply[0][0]',
#                                 128)                              'tf.math.multiply_1[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 128)         0           ['conv2d_17[0][0]']
#  obalAveragePooling2D)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, None, None,   0          ['add[0][0]']
#                                 128)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, None, None,   0          ['conv2d_7[0][0]']
#                                 128)
#
#  conv2d_15 (Conv2D)             (None, None, None,   8256        ['concatenate_1[0][0]']
#                                 64)
#
#  reshape_1 (Reshape)            (None, 1, 1, 128)    0           ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  channel_pooling_1 (ChannelPool  (None, None, None,   0          ['conv2d_17[0][0]']
#  ing)                           2)
#
#  conv2d_9 (Conv2D)              (None, None, None,   33024       ['max_pooling2d_3[0][0]']
#                                 256)
#
#  conv2d_8 (Conv2D)              (None, None, None,   33024       ['max_pooling2d_2[0][0]']
#                                 256)
#
#  add_2 (Add)                    (None, None, None,   0           ['conv2d_1[0][0]',
#                                 64)                               'conv2d_15[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 1, 1, 16)     2064        ['reshape_1[0][0]']
#
#  conv2d_20 (Conv2D)             (None, None, None,   3           ['channel_pooling_1[0][0]']
#                                 1)
#
#  add_1 (Add)                    (None, None, None,   0           ['conv2d_9[0][0]',
#                                 256)                              'conv2d_8[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 1, 1, 128)    2176        ['conv2d_18[0][0]']
#
#  tf.math.sigmoid_1 (TFOpLambda)  (None, None, None,   0          ['conv2d_20[0][0]']
#                                 1)
#
#  conv2d_22 (Conv2D)             (None, None, None,   590080      ['add_1[0][0]']
#                                 256)
#
#  conv2d_56 (Conv2D)             (None, None, None,   4160        ['add_2[0][0]']
#                                 64)
#
#  tf.math.multiply_2 (TFOpLambda  (None, None, None,   0          ['conv2d_17[0][0]',
#  )                              128)                              'conv2d_19[0][0]']
#
#  tf.math.multiply_3 (TFOpLambda  (None, None, None,   0          ['conv2d_17[0][0]',
#  )                              128)                              'tf.math.sigmoid_1[0][0]']
#
#  conv2d_23 (Conv2D)             (None, None, None,   590080      ['conv2d_22[0][0]']
#                                 256)
#
#  conv2d_57 (Conv2D)             (None, None, None,   36928       ['conv2d_56[0][0]']
#                                 64)
#
#  concatenate_3 (Concatenate)    (None, None, None,   0           ['tf.math.multiply_2[0][0]',
#                                 256)                              'tf.math.multiply_3[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 256)         0           ['conv2d_23[0][0]']
#  obalAveragePooling2D)
#
#  max_pooling2d_7 (MaxPooling2D)  (None, None, None,   0          ['add_2[0][0]']
#                                 64)
#
#  max_pooling2d_6 (MaxPooling2D)  (None, None, None,   0          ['conv2d_57[0][0]']
#                                 64)
#
#  conv2d_21 (Conv2D)             (None, None, None,   32896       ['concatenate_3[0][0]']
#                                 128)
#
#  reshape_2 (Reshape)            (None, 1, 1, 256)    0           ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
#  channel_pooling_2 (ChannelPool  (None, None, None,   0          ['conv2d_23[0][0]']
#  ing)                           2)
#
#  conv2d_59 (Conv2D)             (None, None, None,   8320        ['max_pooling2d_7[0][0]']
#                                 128)
#
#  conv2d_58 (Conv2D)             (None, None, None,   8320        ['max_pooling2d_6[0][0]']
#                                 128)
#
#  add_3 (Add)                    (None, None, None,   0           ['add[0][0]',
#                                 128)                              'conv2d_21[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 1, 1, 32)     8224        ['reshape_2[0][0]']
#
#  conv2d_26 (Conv2D)             (None, None, None,   3           ['channel_pooling_2[0][0]']
#                                 1)
#
#  add_14 (Add)                   (None, None, None,   0           ['conv2d_59[0][0]',
#                                 128)                              'conv2d_58[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 1, 1, 256)    8448        ['conv2d_24[0][0]']
#
#  tf.math.sigmoid_2 (TFOpLambda)  (None, None, None,   0          ['conv2d_26[0][0]']
#                                 1)
#
#  conv2d_60 (Conv2D)             (None, None, None,   16512       ['add_14[0][0]']
#                                 128)
#
#  conv2d_64 (Conv2D)             (None, None, None,   16512       ['add_3[0][0]']
#                                 128)
#
#  tf.math.multiply_4 (TFOpLambda  (None, None, None,   0          ['conv2d_23[0][0]',
#  )                              256)                              'conv2d_25[0][0]']
#
#  tf.math.multiply_5 (TFOpLambda  (None, None, None,   0          ['conv2d_23[0][0]',
#  )                              256)                              'tf.math.sigmoid_2[0][0]']
#
#  conv2d_61 (Conv2D)             (None, None, None,   147584      ['conv2d_60[0][0]']
#                                 128)
#
#  conv2d_65 (Conv2D)             (None, None, None,   147584      ['conv2d_64[0][0]']
#                                 128)
#
#  concatenate_5 (Concatenate)    (None, None, None,   0           ['tf.math.multiply_4[0][0]',
#                                 512)                              'tf.math.multiply_5[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, None, None,   0          ['add_14[0][0]']
#                                 128)
#
#  max_pooling2d_8 (MaxPooling2D)  (None, None, None,   0          ['conv2d_61[0][0]']
#                                 128)
#
#  max_pooling2d_11 (MaxPooling2D  (None, None, None,   0          ['add_3[0][0]']
#  )                              128)
#
#  max_pooling2d_10 (MaxPooling2D  (None, None, None,   0          ['conv2d_65[0][0]']
#  )                              128)
#
#  conv2d_27 (Conv2D)             (None, None, None,   131328      ['concatenate_5[0][0]']
#                                 256)
#
#  conv2d_63 (Conv2D)             (None, None, None,   33024       ['max_pooling2d_9[0][0]']
#                                 256)
#
#  conv2d_62 (Conv2D)             (None, None, None,   33024       ['max_pooling2d_8[0][0]']
#                                 256)
#
#  conv2d_67 (Conv2D)             (None, None, None,   33024       ['max_pooling2d_11[0][0]']
#                                 256)
#
#  conv2d_66 (Conv2D)             (None, None, None,   33024       ['max_pooling2d_10[0][0]']
#                                 256)
#
#  add_4 (Add)                    (None, None, None,   0           ['add_1[0][0]',
#                                 256)                              'conv2d_27[0][0]']
#
#  add_15 (Add)                   (None, None, None,   0           ['conv2d_63[0][0]',
#                                 256)                              'conv2d_62[0][0]']
#
#  add_16 (Add)                   (None, None, None,   0           ['conv2d_67[0][0]',
#                                 256)                              'conv2d_66[0][0]']
#
#  conv2d_32 (Conv2D)             (None, None, None,   65792       ['add_4[0][0]']
#                                 256)
#
#  conv2d_44 (Conv2D)             (None, None, None,   4160        ['add_2[0][0]']
#                                 64)
#
#  conv2d_48 (Conv2D)             (None, None, None,   65792       ['add_4[0][0]']
#                                 256)
#
#  add_17 (Add)                   (None, None, None,   0           ['add_15[0][0]',
#                                 256)                              'add_16[0][0]',
#                                                                   'add_4[0][0]']
#
#  conv2d_33 (Conv2D)             (None, None, None,   590080      ['conv2d_32[0][0]']
#                                 256)
#
#  conv2d_45 (Conv2D)             (None, None, None,   36928       ['conv2d_44[0][0]']
#                                 64)
#
#  conv2d_49 (Conv2D)             (None, None, None,   590080      ['conv2d_48[0][0]']
#                                 256)
#
#  global_average_pooling2d_5 (Gl  (None, 256)         0           ['add_17[0][0]']
#  obalAveragePooling2D)
#
#  up_sampling2d_3 (UpSampling2D)  (None, None, None,   0          ['add_4[0][0]']
#                                 256)
#
#  up_sampling2d_2 (UpSampling2D)  (None, None, None,   0          ['conv2d_33[0][0]']
#                                 256)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, None, None,   0          ['add_2[0][0]']
#                                 64)
#
#  max_pooling2d_4 (MaxPooling2D)  (None, None, None,   0          ['conv2d_45[0][0]']
#                                 64)
#
#  up_sampling2d_7 (UpSampling2D)  (None, None, None,   0          ['add_4[0][0]']
#                                 256)
#
#  up_sampling2d_6 (UpSampling2D)  (None, None, None,   0          ['conv2d_49[0][0]']
#                                 256)
#
#  reshape_5 (Reshape)            (None, 1, 1, 256)    0           ['global_average_pooling2d_5[0][0
#                                                                  ]']
#
#  conv2d_35 (Conv2D)             (None, None, None,   32896       ['up_sampling2d_3[0][0]']
#                                 128)
#
#  conv2d_34 (Conv2D)             (None, None, None,   32896       ['up_sampling2d_2[0][0]']
#                                 128)
#
#  conv2d_47 (Conv2D)             (None, None, None,   8320        ['max_pooling2d_5[0][0]']
#                                 128)
#
#  conv2d_46 (Conv2D)             (None, None, None,   8320        ['max_pooling2d_4[0][0]']
#                                 128)
#
#  conv2d_51 (Conv2D)             (None, None, None,   32896       ['up_sampling2d_7[0][0]']
#                                 128)
#
#  conv2d_50 (Conv2D)             (None, None, None,   32896       ['up_sampling2d_6[0][0]']
#                                 128)
#
#  conv2d_68 (Conv2D)             (None, 1, 1, 32)     8224        ['reshape_5[0][0]']
#
#  add_6 (Add)                    (None, None, None,   0           ['conv2d_35[0][0]',
#                                 128)                              'conv2d_34[0][0]']
#
#  add_10 (Add)                   (None, None, None,   0           ['conv2d_47[0][0]',
#                                 128)                              'conv2d_46[0][0]']
#
#  add_11 (Add)                   (None, None, None,   0           ['conv2d_51[0][0]',
#                                 128)                              'conv2d_50[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 1, 1, 256)    8448        ['conv2d_68[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 1, 1, 256)    8448        ['conv2d_68[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 1, 1, 256)    8448        ['conv2d_68[0][0]']
#
#  conv2d_28 (Conv2D)             (None, None, None,   16512       ['add_3[0][0]']
#                                 128)
#
#  conv2d_36 (Conv2D)             (None, None, None,   16512       ['add_6[0][0]']
#                                 128)
#
#  add_12 (Add)                   (None, None, None,   0           ['add_10[0][0]',
#                                 128)                              'add_3[0][0]',
#                                                                   'add_11[0][0]']
#
#  tf.math.multiply_12 (TFOpLambd  (None, None, None,   0          ['add_15[0][0]',
#  a)                             256)                              'conv2d_69[0][0]']
#
#  tf.math.multiply_13 (TFOpLambd  (None, None, None,   0          ['add_16[0][0]',
#  a)                             256)                              'conv2d_70[0][0]']
#
#  tf.math.multiply_14 (TFOpLambd  (None, None, None,   0          ['add_4[0][0]',
#  a)                             256)                              'conv2d_71[0][0]']
#
#  conv2d_29 (Conv2D)             (None, None, None,   147584      ['conv2d_28[0][0]']
#                                 128)
#
#  conv2d_37 (Conv2D)             (None, None, None,   147584      ['conv2d_36[0][0]']
#                                 128)
#
#  global_average_pooling2d_4 (Gl  (None, 128)         0           ['add_12[0][0]']
#  obalAveragePooling2D)
#
#  add_18 (Add)                   (None, None, None,   0           ['tf.math.multiply_12[0][0]',
#                                 256)                              'tf.math.multiply_13[0][0]',
#                                                                   'tf.math.multiply_14[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, None, None,   0          ['add_3[0][0]']
#                                 128)
#
#  up_sampling2d (UpSampling2D)   (None, None, None,   0           ['conv2d_29[0][0]']
#                                 128)
#
#  up_sampling2d_5 (UpSampling2D)  (None, None, None,   0          ['add_6[0][0]']
#                                 128)
#
#  up_sampling2d_4 (UpSampling2D)  (None, None, None,   0          ['conv2d_37[0][0]']
#                                 128)
#
#  reshape_4 (Reshape)            (None, 1, 1, 128)    0           ['global_average_pooling2d_4[0][0
#                                                                  ]']
#
#  conv2d_88 (Conv2D)             (None, None, None,   590080      ['add_18[0][0]']
#                                 256)
#
#  conv2d_31 (Conv2D)             (None, None, None,   8256        ['up_sampling2d_1[0][0]']
#                                 64)
#
#  conv2d_30 (Conv2D)             (None, None, None,   8256        ['up_sampling2d[0][0]']
#                                 64)
#
#  conv2d_39 (Conv2D)             (None, None, None,   8256        ['up_sampling2d_5[0][0]']
#                                 64)
#
#  conv2d_38 (Conv2D)             (None, None, None,   8256        ['up_sampling2d_4[0][0]']
#                                 64)
#
#  conv2d_52 (Conv2D)             (None, 1, 1, 16)     2064        ['reshape_4[0][0]']
#
#  conv2d_89 (Conv2D)             (None, None, None,   590080      ['conv2d_88[0][0]']
#                                 256)
#
#  add_5 (Add)                    (None, None, None,   0           ['conv2d_31[0][0]',
#                                 64)                               'conv2d_30[0][0]']
#
#  add_7 (Add)                    (None, None, None,   0           ['conv2d_39[0][0]',
#                                 64)                               'conv2d_38[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 1, 1, 128)    2176        ['conv2d_52[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 1, 1, 128)    2176        ['conv2d_52[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 1, 1, 128)    2176        ['conv2d_52[0][0]']
#
#  global_average_pooling2d_8 (Gl  (None, 256)         0           ['conv2d_89[0][0]']
#  obalAveragePooling2D)
#
#  add_8 (Add)                    (None, None, None,   0           ['add_2[0][0]',
#                                 64)                               'add_5[0][0]',
#                                                                   'add_7[0][0]']
#
#  tf.math.multiply_9 (TFOpLambda  (None, None, None,   0          ['add_10[0][0]',
#  )                              128)                              'conv2d_53[0][0]']
#
#  tf.math.multiply_10 (TFOpLambd  (None, None, None,   0          ['add_3[0][0]',
#  a)                             128)                              'conv2d_54[0][0]']
#
#  tf.math.multiply_11 (TFOpLambd  (None, None, None,   0          ['add_11[0][0]',
#  a)                             128)                              'conv2d_55[0][0]']
#
#  reshape_8 (Reshape)            (None, 1, 1, 256)    0           ['global_average_pooling2d_8[0][0
#                                                                  ]']
#
#  channel_pooling_5 (ChannelPool  (None, None, None,   0          ['conv2d_89[0][0]']
#  ing)                           2)
#
#  global_average_pooling2d_3 (Gl  (None, 64)          0           ['add_8[0][0]']
#  obalAveragePooling2D)
#
#  add_13 (Add)                   (None, None, None,   0           ['tf.math.multiply_9[0][0]',
#                                 128)                              'tf.math.multiply_10[0][0]',
#                                                                   'tf.math.multiply_11[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 1, 1, 32)     8224        ['reshape_8[0][0]']
#
#  conv2d_92 (Conv2D)             (None, None, None,   3           ['channel_pooling_5[0][0]']
#                                 1)
#
#  reshape_3 (Reshape)            (None, 1, 1, 64)     0           ['global_average_pooling2d_3[0][0
#                                                                  ]']
#
#  conv2d_78 (Conv2D)             (None, None, None,   147584      ['add_13[0][0]']
#                                 128)
#
#  conv2d_91 (Conv2D)             (None, 1, 1, 256)    8448        ['conv2d_90[0][0]']
#
#  tf.math.sigmoid_5 (TFOpLambda)  (None, None, None,   0          ['conv2d_92[0][0]']
#                                 1)
#
#  conv2d_40 (Conv2D)             (None, 1, 1, 8)      520         ['reshape_3[0][0]']
#
#  conv2d_79 (Conv2D)             (None, None, None,   147584      ['conv2d_78[0][0]']
#                                 128)
#
#  tf.math.multiply_19 (TFOpLambd  (None, None, None,   0          ['conv2d_89[0][0]',
#  a)                             256)                              'conv2d_91[0][0]']
#
#  tf.math.multiply_20 (TFOpLambd  (None, None, None,   0          ['conv2d_89[0][0]',
#  a)                             256)                              'tf.math.sigmoid_5[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 1, 1, 64)     576         ['conv2d_40[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 1, 1, 64)     576         ['conv2d_40[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 1, 1, 64)     576         ['conv2d_40[0][0]']
#
#  global_average_pooling2d_7 (Gl  (None, 128)         0           ['conv2d_79[0][0]']
#  obalAveragePooling2D)
#
#  concatenate_11 (Concatenate)   (None, None, None,   0           ['tf.math.multiply_19[0][0]',
#                                 512)                              'tf.math.multiply_20[0][0]']
#
#  tf.math.multiply_6 (TFOpLambda  (None, None, None,   0          ['add_2[0][0]',
#  )                              64)                               'conv2d_41[0][0]']
#
#  tf.math.multiply_7 (TFOpLambda  (None, None, None,   0          ['add_5[0][0]',
#  )                              64)                               'conv2d_42[0][0]']
#
#  tf.math.multiply_8 (TFOpLambda  (None, None, None,   0          ['add_7[0][0]',
#  )                              64)                               'conv2d_43[0][0]']
#
#  reshape_7 (Reshape)            (None, 1, 1, 128)    0           ['global_average_pooling2d_7[0][0
#                                                                  ]']
#
#  channel_pooling_4 (ChannelPool  (None, None, None,   0          ['conv2d_79[0][0]']
#  ing)                           2)
#
#  conv2d_93 (Conv2D)             (None, None, None,   131328      ['concatenate_11[0][0]']
#                                 256)
#
#  add_9 (Add)                    (None, None, None,   0           ['tf.math.multiply_6[0][0]',
#                                 64)                               'tf.math.multiply_7[0][0]',
# ...
#                                 64)
#
#  tf.math.multiply_137 (TFOpLamb  (None, None, None,   0          ['conv2d_608[0][0]',
#  da)                            128)                              'conv2d_610[0][0]']
#
#  tf.math.multiply_138 (TFOpLamb  (None, None, None,   0          ['conv2d_608[0][0]',
#  da)                            128)                              'tf.math.sigmoid_34[0][0]']
#
#  conv2d_624 (Conv2D)            (None, None, None,   590080      ['conv2d_623[0][0]']
#                                 256)
#
#  global_average_pooling2d_56 (G  (None, 64)          0           ['conv2d_602[0][0]']
#  lobalAveragePooling2D)
#
#  concatenate_69 (Concatenate)   (None, None, None,   0           ['tf.math.multiply_137[0][0]',
#                                 256)                              'tf.math.multiply_138[0][0]']
#
#  up_sampling2d_81 (UpSampling2D  (None, None, None,   0          ['add_164[0][0]']
#  )                              256)
#
#  up_sampling2d_80 (UpSampling2D  (None, None, None,   0          ['conv2d_624[0][0]']
#  )                              256)
#
#  reshape_56 (Reshape)           (None, 1, 1, 64)     0           ['global_average_pooling2d_56[0][
#                                                                  0]']
#
#  channel_pooling_33 (ChannelPoo  (None, None, None,   0          ['conv2d_602[0][0]']
#  ling)                          2)
#
#  conv2d_612 (Conv2D)            (None, None, None,   32896       ['concatenate_69[0][0]']
#                                 128)
#
#  conv2d_626 (Conv2D)            (None, None, None,   32896       ['up_sampling2d_81[0][0]']
#                                 128)
#
#  conv2d_625 (Conv2D)            (None, None, None,   32896       ['up_sampling2d_80[0][0]']
#                                 128)
#
#  conv2d_603 (Conv2D)            (None, 1, 1, 8)      520         ['reshape_56[0][0]']
#
#  conv2d_605 (Conv2D)            (None, None, None,   3           ['channel_pooling_33[0][0]']
#                                 1)
#
#  add_162 (Add)                  (None, None, None,   0           ['add_155[0][0]',
#                                 128)                              'conv2d_612[0][0]']
#
#  add_165 (Add)                  (None, None, None,   0           ['conv2d_626[0][0]',
#                                 128)                              'conv2d_625[0][0]']
#
#  conv2d_604 (Conv2D)            (None, 1, 1, 64)     576         ['conv2d_603[0][0]']
#
#  tf.math.sigmoid_33 (TFOpLambda  (None, None, None,   0          ['conv2d_605[0][0]']
#  )                              1)
#
#  conv2d_613 (Conv2D)            (None, None, None,   16512       ['add_162[0][0]']
#                                 128)
#
#  conv2d_627 (Conv2D)            (None, None, None,   16512       ['add_165[0][0]']
#                                 128)
#
#  tf.math.multiply_135 (TFOpLamb  (None, None, None,   0          ['conv2d_602[0][0]',
#  da)                            64)                               'conv2d_604[0][0]']
#
#  tf.math.multiply_136 (TFOpLamb  (None, None, None,   0          ['conv2d_602[0][0]',
#  da)                            64)                               'tf.math.sigmoid_33[0][0]']
#
#  conv2d_614 (Conv2D)            (None, None, None,   147584      ['conv2d_613[0][0]']
#                                 128)
#
#  conv2d_628 (Conv2D)            (None, None, None,   147584      ['conv2d_627[0][0]']
#                                 128)
#
#  concatenate_67 (Concatenate)   (None, None, None,   0           ['tf.math.multiply_135[0][0]',
#                                 128)                              'tf.math.multiply_136[0][0]']
#
#  up_sampling2d_79 (UpSampling2D  (None, None, None,   0          ['add_162[0][0]']
#  )                              128)
#  up_sampling2d_78 (UpSampling2D  (None, None, None,   0          ['conv2d_614[0][0]']
#  )                              128)
#
#  up_sampling2d_83 (UpSampling2D  (None, None, None,   0          ['add_165[0][0]']
#  )                              128)
#
#  up_sampling2d_82 (UpSampling2D  (None, None, None,   0          ['conv2d_628[0][0]']
#  )                              128)
#
#  conv2d_606 (Conv2D)            (None, None, None,   8256        ['concatenate_67[0][0]']
#                                 64)
#
#  conv2d_616 (Conv2D)            (None, None, None,   8256        ['up_sampling2d_79[0][0]']
#                                 64)
#
#  conv2d_615 (Conv2D)            (None, None, None,   8256        ['up_sampling2d_78[0][0]']
#                                 64)
#
#  conv2d_630 (Conv2D)            (None, None, None,   8256        ['up_sampling2d_83[0][0]']
#                                 64)
#
#  conv2d_629 (Conv2D)            (None, None, None,   8256        ['up_sampling2d_82[0][0]']
#                                 64)
#
#  add_161 (Add)                  (None, None, None,   0           ['add_151[0][0]',
#                                 64)                               'conv2d_606[0][0]']
#
#  add_163 (Add)                  (None, None, None,   0           ['conv2d_616[0][0]',
#                                 64)                               'conv2d_615[0][0]']
#
#  add_166 (Add)                  (None, None, None,   0           ['conv2d_630[0][0]',
#                                 64)                               'conv2d_629[0][0]']
#
#  add_167 (Add)                  (None, None, None,   0           ['add_161[0][0]',
#                                 64)                               'add_163[0][0]',
#                                                                   'add_166[0][0]']
#
#  global_average_pooling2d_59 (G  (None, 64)          0           ['add_167[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_59 (Reshape)           (None, 1, 1, 64)     0           ['global_average_pooling2d_59[0][
#                                                                  0]']
#
#  conv2d_631 (Conv2D)            (None, 1, 1, 8)      520         ['reshape_59[0][0]']
#
#  conv2d_632 (Conv2D)            (None, 1, 1, 64)     576         ['conv2d_631[0][0]']
#
#  conv2d_633 (Conv2D)            (None, 1, 1, 64)     576         ['conv2d_631[0][0]']
#
#  conv2d_634 (Conv2D)            (None, 1, 1, 64)     576         ['conv2d_631[0][0]']
#
#  tf.math.multiply_141 (TFOpLamb  (None, None, None,   0          ['add_161[0][0]',
#  da)                            64)                               'conv2d_632[0][0]']
#
#  tf.math.multiply_142 (TFOpLamb  (None, None, None,   0          ['add_163[0][0]',
#  da)                            64)                               'conv2d_633[0][0]']
#
#  tf.math.multiply_143 (TFOpLamb  (None, None, None,   0          ['add_166[0][0]',
#  da)                            64)                               'conv2d_634[0][0]']
#
#  add_168 (Add)                  (None, None, None,   0           ['tf.math.multiply_141[0][0]',
#                                 64)                               'tf.math.multiply_142[0][0]',
#                                                                   'tf.math.multiply_143[0][0]']
#
#  conv2d_635 (Conv2D)            (None, None, None,   36928       ['add_168[0][0]']
#                                 64)
#
#  add_169 (Add)                  (None, None, None,   0           ['add_141[0][0]',
#                                 64)                               'conv2d_635[0][0]']
#
#  conv2d_636 (Conv2D)            (None, None, None,   36928       ['add_169[0][0]']
#                                 64)
#
#  add_170 (Add)                  (None, None, None,   0           ['conv2d_636[0][0]',
#                                 64)                               'add_113[0][0]']
#
#  conv2d_637 (Conv2D)            (None, None, None,   1731        ['add_170[0][0]']
#                                 3)
#
#  add_171 (Add)                  (None, None, None,   0           ['input_1[0][0]',
#                                 3)                                'conv2d_637[0][0]']
#
# ==================================================================================================
# Total params: 44,157,007
# Trainable params: 44,157,007
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training
#
# - We train MIRNet using **Charbonnier Loss** as the loss function and **Adam
# Optimizer** with a learning rate of `1e-4`.
# - We use **Peak Signal Noise Ratio** or PSNR as a metric which is an expression for the
# ratio between the maximum possible value (power) of a signal and the power of distorting
# noise that affects the quality of its representation.

# %%
def charbonnier_loss(y_true, y_pred):
    return tf.reduce_mean(tf.sqrt(tf.square(y_true - y_pred) + tf.square(1e-3)))


def peak_signal_noise_ratio(y_true, y_pred):
    return tf.image.psnr(y_pred, y_true, max_val=255.0)


optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
model.compile(
    optimizer=optimizer,
    loss=charbonnier_loss,
    metrics=[peak_signal_noise_ratio],
)

# %%
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=50,
    callbacks=[
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor="val_peak_signal_noise_ratio",
            factor=0.5,
            patience=5,
            verbose=0,
            min_delta=1e-7,
            mode="max",
        ),
        tf.keras.callbacks.ModelCheckpoint(
            'model/MirNet_model.h5' ,
            monitor = 'val_peak_signal_noise_ratio',
            verbose = 0,
            save_best_only=True,
            mode = 'max',
            save_weights_only=True,
            save_freq='epoch'
        )
    ]
)
# Out:
# Epoch 1/50
# 75/75 [==============================] - 339s 1s/step - loss: 0.2055 - peak_signal_noise_ratio: 61.8724 - val_loss: 0.1404 - val_peak_signal_noise_ratio: 65.2742 - lr: 1.0000e-04
# Epoch 2/50
# 75/75 [==============================] - 38s 508ms/step - loss: 0.1734 - peak_signal_noise_ratio: 63.4338 - val_loss: 0.1232 - val_peak_signal_noise_ratio: 66.0106 - lr: 1.0000e-04
# Epoch 3/50
# 75/75 [==============================] - 32s 433ms/step - loss: 0.1700 - peak_signal_noise_ratio: 63.4526 - val_loss: 0.1305 - val_peak_signal_noise_ratio: 65.5550 - lr: 1.0000e-04
# Epoch 4/50
# 75/75 [==============================] - 37s 500ms/step - loss: 0.1676 - peak_signal_noise_ratio: 63.5873 - val_loss: 0.1159 - val_peak_signal_noise_ratio: 66.4184 - lr: 1.0000e-04
# Epoch 5/50
# 75/75 [==============================] - 32s 433ms/step - loss: 0.2177 - peak_signal_noise_ratio: 63.4282 - val_loss: 0.1499 - val_peak_signal_noise_ratio: 64.9530 - lr: 1.0000e-04
# Epoch 6/50
# 75/75 [==============================] - 32s 432ms/step - loss: 0.1698 - peak_signal_noise_ratio: 63.5635 - val_loss: 0.1260 - val_peak_signal_noise_ratio: 65.7053 - lr: 1.0000e-04
# Epoch 7/50
# 75/75 [==============================] - 32s 433ms/step - loss: 0.1494 - peak_signal_noise_ratio: 64.5192 - val_loss: 0.1315 - val_peak_signal_noise_ratio: 65.8030 - lr: 1.0000e-04
# Epoch 8/50
# 75/75 [==============================] - 32s 432ms/step - loss: 0.1587 - peak_signal_noise_ratio: 63.9566 - val_loss: 0.1168 - val_peak_signal_noise_ratio: 66.1958 - lr: 1.0000e-04
# Epoch 9/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1552 - peak_signal_noise_ratio: 64.1355
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 75/75 [==============================] - 32s 433ms/step - loss: 0.1552 - peak_signal_noise_ratio: 64.1355 - val_loss: 0.1160 - val_peak_signal_noise_ratio: 66.3555 - lr: 1.0000e-04
# Epoch 10/50
# 75/75 [==============================] - 32s 433ms/step - loss: 0.1609 - peak_signal_noise_ratio: 64.0983 - val_loss: 0.1180 - val_peak_signal_noise_ratio: 66.3266 - lr: 5.0000e-05
# Epoch 11/50
# 75/75 [==============================] - 38s 502ms/step - loss: 0.1425 - peak_signal_noise_ratio: 64.7362 - val_loss: 0.1084 - val_peak_signal_noise_ratio: 67.2128 - lr: 5.0000e-05
# Epoch 12/50
# 75/75 [==============================] - 33s 445ms/step - loss: 0.1455 - peak_signal_noise_ratio: 65.0893 - val_loss: 0.1142 - val_peak_signal_noise_ratio: 66.9096 - lr: 5.0000e-05
# Epoch 13/50
# 75/75 [==============================] - 33s 434ms/step - loss: 0.1429 - peak_signal_noise_ratio: 64.9288 - val_loss: 0.1152 - val_peak_signal_noise_ratio: 66.7581 - lr: 5.0000e-05
# Epoch 14/50
# 75/75 [==============================] - 33s 434ms/step - loss: 0.1478 - peak_signal_noise_ratio: 64.8042 - val_loss: 0.1115 - val_peak_signal_noise_ratio: 67.0054 - lr: 5.0000e-05
# Epoch 15/50
# 75/75 [==============================] - 37s 500ms/step - loss: 0.1391 - peak_signal_noise_ratio: 65.0665 - val_loss: 0.1107 - val_peak_signal_noise_ratio: 67.2137 - lr: 5.0000e-05
# Epoch 16/50
# 75/75 [==============================] - 38s 501ms/step - loss: 0.1372 - peak_signal_noise_ratio: 65.2181 - val_loss: 0.1054 - val_peak_signal_noise_ratio: 67.5630 - lr: 5.0000e-05
# Epoch 17/50
# 75/75 [==============================] - 33s 434ms/step - loss: 0.1363 - peak_signal_noise_ratio: 65.3890 - val_loss: 0.1141 - val_peak_signal_noise_ratio: 66.8889 - lr: 5.0000e-05
# Epoch 18/50
# 75/75 [==============================] - 32s 433ms/step - loss: 0.1386 - peak_signal_noise_ratio: 65.2685 - val_loss: 0.1070 - val_peak_signal_noise_ratio: 67.3296 - lr: 5.0000e-05
# Epoch 19/50
# 75/75 [==============================] - 37s 501ms/step - loss: 0.1330 - peak_signal_noise_ratio: 65.5940 - val_loss: 0.1027 - val_peak_signal_noise_ratio: 67.6153 - lr: 5.0000e-05
# Epoch 20/50
# 75/75 [==============================] - 33s 433ms/step - loss: 0.1325 - peak_signal_noise_ratio: 65.6621 - val_loss: 0.1091 - val_peak_signal_noise_ratio: 67.1845 - lr: 5.0000e-05
# Epoch 21/50
# 75/75 [==============================] - 33s 444ms/step - loss: 0.1263 - peak_signal_noise_ratio: 66.0150 - val_loss: 0.1128 - val_peak_signal_noise_ratio: 66.9751 - lr: 5.0000e-05
# Epoch 22/50
# 75/75 [==============================] - 37s 492ms/step - loss: 0.1329 - peak_signal_noise_ratio: 65.7091 - val_loss: 0.1011 - val_peak_signal_noise_ratio: 67.8954 - lr: 5.0000e-05
# Epoch 23/50
# 75/75 [==============================] - 33s 434ms/step - loss: 0.1331 - peak_signal_noise_ratio: 65.6426 - val_loss: 0.1025 - val_peak_signal_noise_ratio: 67.4436 - lr: 5.0000e-05
# Epoch 24/50
# 75/75 [==============================] - 32s 433ms/step - loss: 0.1324 - peak_signal_noise_ratio: 65.6754 - val_loss: 0.1178 - val_peak_signal_noise_ratio: 66.2227 - lr: 5.0000e-05
# Epoch 25/50
# 75/75 [==============================] - 32s 434ms/step - loss: 0.1281 - peak_signal_noise_ratio: 66.0202 - val_loss: 0.1056 - val_peak_signal_noise_ratio: 67.3256 - lr: 5.0000e-05
# Epoch 26/50
# 75/75 [==============================] - 32s 433ms/step - loss: 0.1259 - peak_signal_noise_ratio: 66.0772 - val_loss: 0.1026 - val_peak_signal_noise_ratio: 67.6702 - lr: 5.0000e-05
# Epoch 27/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1260 - peak_signal_noise_ratio: 66.0775
# Epoch 27: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 75/75 [==============================] - 32s 434ms/step - loss: 0.1260 - peak_signal_noise_ratio: 66.0775 - val_loss: 0.1155 - val_peak_signal_noise_ratio: 66.4875 - lr: 5.0000e-05
# Epoch 28/50
# 75/75 [==============================] - 32s 433ms/step - loss: 0.1240 - peak_signal_noise_ratio: 66.2563 - val_loss: 0.1124 - val_peak_signal_noise_ratio: 66.8597 - lr: 2.5000e-05
# Epoch 29/50
# 75/75 [==============================] - 32s 432ms/step - loss: 0.1233 - peak_signal_noise_ratio: 66.2302 - val_loss: 0.1071 - val_peak_signal_noise_ratio: 67.3637 - lr: 2.5000e-05
# Epoch 30/50
# 75/75 [==============================] - 32s 432ms/step - loss: 0.1159 - peak_signal_noise_ratio: 66.6880 - val_loss: 0.1136 - val_peak_signal_noise_ratio: 66.8015 - lr: 2.5000e-05
# Epoch 31/50
# 75/75 [==============================] - 33s 444ms/step - loss: 0.1186 - peak_signal_noise_ratio: 66.5008 - val_loss: 0.1189 - val_peak_signal_noise_ratio: 66.4066 - lr: 2.5000e-05
# Epoch 32/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1239 - peak_signal_noise_ratio: 66.3049
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 75/75 [==============================] - 32s 432ms/step - loss: 0.1239 - peak_signal_noise_ratio: 66.3049 - val_loss: 0.1084 - val_peak_signal_noise_ratio: 67.1336 - lr: 2.5000e-05
# Epoch 33/50
# 75/75 [==============================] - 32s 432ms/step - loss: 0.1248 - peak_signal_noise_ratio: 66.2819 - val_loss: 0.1087 - val_peak_signal_noise_ratio: 67.2940 - lr: 1.2500e-05
# Epoch 34/50
# 75/75 [==============================] - 33s 434ms/step - loss: 0.1156 - peak_signal_noise_ratio: 66.8385 - val_loss: 0.1077 - val_peak_signal_noise_ratio: 67.4104 - lr: 1.2500e-05
# Epoch 35/50
# 75/75 [==============================] - 32s 433ms/step - loss: 0.1144 - peak_signal_noise_ratio: 66.8089 - val_loss: 0.1048 - val_peak_signal_noise_ratio: 67.3350 - lr: 1.2500e-05
# Epoch 36/50
# 75/75 [==============================] - 32s 433ms/step - loss: 0.1129 - peak_signal_noise_ratio: 67.0892 - val_loss: 0.1115 - val_peak_signal_noise_ratio: 67.0771 - lr: 1.2500e-05
# Epoch 37/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1157 - peak_signal_noise_ratio: 66.8601
# Epoch 37: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 75/75 [==============================] - 32s 434ms/step - loss: 0.1157 - peak_signal_noise_ratio: 66.8601 - val_loss: 0.1047 - val_peak_signal_noise_ratio: 67.5520 - lr: 1.2500e-05
# Epoch 38/50
# 75/75 [==============================] - 32s 434ms/step - loss: 0.1153 - peak_signal_noise_ratio: 66.7504 - val_loss: 0.1107 - val_peak_signal_noise_ratio: 66.9395 - lr: 6.2500e-06
# Epoch 39/50
# 75/75 [==============================] - 32s 433ms/step - loss: 0.1163 - peak_signal_noise_ratio: 66.8015 - val_loss: 0.1123 - val_peak_signal_noise_ratio: 66.9797 - lr: 6.2500e-06
# Epoch 40/50
# 75/75 [==============================] - 33s 443ms/step - loss: 0.1132 - peak_signal_noise_ratio: 66.9106 - val_loss: 0.1090 - val_peak_signal_noise_ratio: 67.1804 - lr: 6.2500e-06
# Epoch 41/50
# 75/75 [==============================] - 32s 434ms/step - loss: 0.1133 - peak_signal_noise_ratio: 66.9518 - val_loss: 0.1043 - val_peak_signal_noise_ratio: 67.6490 - lr: 6.2500e-06
# Epoch 42/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1125 - peak_signal_noise_ratio: 67.0554
# Epoch 42: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 75/75 [==============================] - 32s 433ms/step - loss: 0.1125 - peak_signal_noise_ratio: 67.0554 - val_loss: 0.1070 - val_peak_signal_noise_ratio: 67.2557 - lr: 6.2500e-06
# Epoch 43/50
# 75/75 [==============================] - 32s 434ms/step - loss: 0.1121 - peak_signal_noise_ratio: 67.0811 - val_loss: 0.1078 - val_peak_signal_noise_ratio: 67.2263 - lr: 3.1250e-06
# Epoch 44/50
# 75/75 [==============================] - 32s 433ms/step - loss: 0.1070 - peak_signal_noise_ratio: 67.5150 - val_loss: 0.1038 - val_peak_signal_noise_ratio: 67.5194 - lr: 3.1250e-06
# Epoch 45/50
# 75/75 [==============================] - 33s 434ms/step - loss: 0.1072 - peak_signal_noise_ratio: 67.4793 - val_loss: 0.1085 - val_peak_signal_noise_ratio: 67.2731 - lr: 3.1250e-06
# Epoch 46/50
# 75/75 [==============================] - 32s 433ms/step - loss: 0.1082 - peak_signal_noise_ratio: 67.1482 - val_loss: 0.1121 - val_peak_signal_noise_ratio: 67.1277 - lr: 3.1250e-06
# Epoch 47/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1080 - peak_signal_noise_ratio: 67.2333
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 75/75 [==============================] - 32s 432ms/step - loss: 0.1080 - peak_signal_noise_ratio: 67.2333 - val_loss: 0.1130 - val_peak_signal_noise_ratio: 67.0940 - lr: 3.1250e-06
# Epoch 48/50
# 75/75 [==============================] - 32s 432ms/step - loss: 0.1114 - peak_signal_noise_ratio: 67.0906 - val_loss: 0.1084 - val_peak_signal_noise_ratio: 67.2645 - lr: 1.5625e-06
# Epoch 49/50
# 75/75 [==============================] - 32s 433ms/step - loss: 0.1081 - peak_signal_noise_ratio: 67.3697 - val_loss: 0.1100 - val_peak_signal_noise_ratio: 67.1306 - lr: 1.5625e-06
# Epoch 50/50
# 75/75 [==============================] - 33s 444ms/step - loss: 0.1128 - peak_signal_noise_ratio: 67.0484 - val_loss: 0.1111 - val_peak_signal_noise_ratio: 67.0405 - lr: 1.5625e-06

# %%
with plt.style.context(style='fivethirtyeight'):
    fig,axes=plt.subplots(nrows=1,ncols=2,figsize=(18,8))
    axes[0].plot(history.history["peak_signal_noise_ratio"],label="peak_signal_noise_ratio")
    axes[0].plot(history.history["val_peak_signal_noise_ratio"],label="val_peak_signal_noise_ratio")
    axes[0].set_title(label='Accuracy plot-graphs')
    axes[0].set_xlabel(xlabel='Number of epochs')
    axes[0].set_ylabel(ylabel='Accuracy')
    axes[0].legend()
    axes[1].plot(history.history["loss"],label="loss")
    axes[1].plot(history.history["val_loss"],label="val_loss")
    axes[1].set_title(label='Loss plot-graphs')
    axes[1].set_xlabel(xlabel='Number of epochs')
    axes[1].set_ylabel(ylabel='Loss')
    axes[1].legend()
    fig.tight_layout()
    plt.show()

# %% [markdown]
# ## Inference

# %%
def plot_results(images, titles, figure_size=(12, 12)):
    fig = plt.figure(figsize=figure_size)
    for i in range(len(images)):
        fig.add_subplot(1, len(images), i + 1).set_title(titles[i])
        _ = plt.imshow(images[i])
        plt.axis("off")
    plt.show()


def infer(original_image):
    image = tf.keras.utils.img_to_array(original_image)
    image = image.astype("float32") / 255.0
    image = np.expand_dims(image, axis=0)
    output = model.predict(image, verbose=0)
    output_image = output[0] * 255.0
    output_image = output_image.clip(0, 255)
    output_image = output_image.reshape(
        (np.shape(output_image)[0], np.shape(output_image)[1], 3)
    )
    output_image = Image.fromarray(np.uint8(output_image))
    original_image = Image.fromarray(np.uint8(original_image))
    return output_image

# %%
for low_light_image in random.sample(test_low_light_images, 6):
    original_image = Image.open(low_light_image)
    enhanced_image = infer(original_image)
    plot_results(
        [original_image, ImageOps.autocontrast(original_image), enhanced_image],
        ["Original", "PIL Autocontrast", "MIRNet Enhanced"],
        (20, 12),
    )
